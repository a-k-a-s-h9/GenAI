# %% [markdown]
# Import matplotlib.pyplot as plt and set %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Exercise 1
#
# Follow along with these steps:
#
# Create a figure object called fig using plt.figure()
#
# Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
#
# Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
x=np.arange(0,100)
y=x*2
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("title")
ax.plot(x,y)

# %% [markdown]
# Exercise 2
#
# Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.

# %%
fig1=plt.figure()
ax1=fig1.add_axes([0,0,1,1])
ax2=fig1.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# Now plot (x,y) on both axes. And call your figure object to show it.

# %%
fig1=plt.figure()
ax1=fig1.add_axes([0,0,1,1])
ax2=fig1.add_axes([0.2,0.5,0.2,0.2])
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax1.plot(x,y)
ax2.plot(x,y)

# %% [markdown]
# Exercise 3
#
# Create the plot below by adding two axes to a figure object at [0,0,1,1] and
# [0.2,0.5,.4,.4]

# %%
fig2=plt.figure()
ax1=fig2.add_axes([0,0,1,1])
ax2=fig2.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:

# %%
fig2=plt.figure()
ax1=fig2.add_axes([0,0,1,1])
ax2=fig2.add_axes([0.1,0.5,0.4,0.4])
z=x**2
ax1.plot(x,z)
ax1.set_xlabel("x")
ax1.set_ylabel("z")
ax2.set_xlim(20,22)
ax2.set_ylim(30,50)
ax2.plot(x,y)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_title("zoom")
# Out:
# Text(0.5, 1.0, 'zoom')

# %% [markdown]
# Exercise 4
#
# Use plt.subplots(nrows=1, ncols=2) to create the plot below.

# %%
fig3,axes=plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style

# %%
fig3,axes=plt.subplots(nrows=1,ncols=2,)
axes[0].plot(x,y,color='blue',linewidth=3,linestyle='--')
axes[1].plot(x,z,color='red',linewidth=3,linestyle='-')

# %% [markdown]
# See if you can resize the plot by adding the figsize() argument in plt.subplots() are
# copying and pasting your previous code.

# %%
fig3,axes=plt.subplots(nrows=1,ncols=2,figsize=(12,2))
axes[0].plot(x,y,color='blue',linewidth=3,linestyle='--')
axes[1].plot(x,z,color='red',linewidth=3,linestyle='-')
